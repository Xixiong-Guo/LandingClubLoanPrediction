# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.simplefilter('ignore')

# %%
# import the preliminary cleaned data in last section
data = pd.read_csv('./data.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1295896 entries, 0 to 1295895
# Data columns (total 72 columns):
# loan_amnt                     1295864 non-null float64
# funded_amnt                   1295864 non-null float64
# funded_amnt_inv               1295864 non-null float64
# term                          1295864 non-null object
# int_rate                      1295864 non-null object
# installment                   1295864 non-null float64
# grade                         1295864 non-null object
# sub_grade                     1295864 non-null object
# emp_title                     1208774 non-null object
# emp_length                    1212582 non-null object
# home_ownership                1295864 non-null object
# annual_inc                    1295864 non-null float64
# verification_status           1295864 non-null object
# purpose                       1295864 non-null object
# title                         1276095 non-null object
# zip_code                      1295863 non-null object
# addr_state                    1295864 non-null object
# dti                           1295256 non-null float64
# delinq_2yrs                   1295864 non-null float64
# earliest_cr_line              1295864 non-null object
# inq_last_6mths                1295863 non-null float64
# open_acc                      1295864 non-null float64
# pub_rec                       1295864 non-null float64
# revol_bal                     1295864 non-null float64
# revol_util                    1295014 non-null object
# total_acc                     1295864 non-null float64
# initial_list_status           1295864 non-null object
# collections_12_mths_ex_med    1295864 non-null float64
# application_type              1295864 non-null object
# acc_now_delinq                1295864 non-null float64
# tot_coll_amt                  1295864 non-null float64
# tot_cur_bal                   1295864 non-null float64
# total_rev_hi_lim              1295864 non-null float64
# acc_open_past_24mths          1295864 non-null float64
# avg_cur_bal                   1295840 non-null float64
# bc_open_to_buy                1281191 non-null float64
# bc_util                       1280415 non-null float64
# chargeoff_within_12_mths      1295864 non-null float64
# delinq_amnt                   1295864 non-null float64
# mo_sin_old_il_acct            1258212 non-null float64
# mo_sin_old_rev_tl_op          1295864 non-null float64
# mo_sin_rcnt_rev_tl_op         1295864 non-null float64
# mo_sin_rcnt_tl                1295864 non-null float64
# mort_acc                      1295864 non-null float64
# mths_since_recent_bc          1282046 non-null float64
# mths_since_recent_inq         1170717 non-null float64
# num_accts_ever_120_pd         1295864 non-null float64
# num_actv_bc_tl                1295864 non-null float64
# num_actv_rev_tl               1295864 non-null float64
# num_bc_sats                   1295864 non-null float64
# num_bc_tl                     1295864 non-null float64
# num_il_tl                     1295864 non-null float64
# num_op_rev_tl                 1295864 non-null float64
# num_rev_accts                 1295863 non-null float64
# num_rev_tl_bal_gt_0           1295864 non-null float64
# num_sats                      1295864 non-null float64
# num_tl_120dpd_2m              1238650 non-null float64
# num_tl_30dpd                  1295864 non-null float64
# num_tl_90g_dpd_24m            1295864 non-null float64
# num_tl_op_past_12m            1295864 non-null float64
# pct_tl_nvr_dlq                1295863 non-null float64
# percent_bc_gt_75              1280772 non-null float64
# pub_rec_bankruptcies          1295864 non-null float64
# tax_liens                     1295864 non-null float64
# tot_hi_cred_lim               1295864 non-null float64
# total_bal_ex_mort             1295864 non-null float64
# total_bc_limit                1295864 non-null float64
# total_il_high_credit_limit    1295864 non-null float64
# hardship_flag                 1295864 non-null object
# debt_settlement_flag          1295864 non-null object
# year                          1295896 non-null int64
# target                        1295896 non-null int64
# dtypes: float64(52), int64(2), object(18)
# memory usage: 711.9+ MB

# %% [markdown]
# ## Split into train and test datasets

# %%
count_year=data['year'].value_counts()
print(count_year)
# Out:
# 2015    383794
# 2016    347678
# 2014    228978
# 2017    215424
# 2018    108659
# 2019     11363
# Name: year, dtype: int64

# %%
# To see the percentage of bad loan for each year is independent or not?
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,6))
sns.countplot(x='year', hue='target', data=data, ax=ax[0])
sns.barplot(x='year', y='target', data=data, ax=ax[1])
plt.tight_layout()
plt.show()

# %% [markdown]
# The percentage of default loan for each year is found to be at relative close range.
# Therefore, we choose Year 2014 - 2017, as the training data, and Year 2018-2019 as the test data.

# %%
train = data.loc[data['year'] .isin(['2014','2015','2016','2017'])]
test = data.loc[data['year'] .isin(['2018','2019'])]
print('Train data shape:',train.shape)
print('Test data shape:',test.shape)
# Out:
# Train data shape: (1175874, 72)
# Test data shape: (120022, 72)

# %%
train['target'].value_counts()
# Out:
# 0    917612
# 1    258262
# Name: target, dtype: int64

# %%
test['target'].value_counts()
# Out:
# 0    84607
# 1    35415
# Name: target, dtype: int64

# %% [markdown]
# ## Feature engineering
#
# ### Missing data imputation

# %%
# missing value proportions 
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(6)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information greater than 20%
        return mis_val_table_ren_columns
    
missing_values_table(train)
# Out:
# Your selected dataframe has 72 columns.
# There are 70 columns that have missing values.
#                             Missing Values  % of Total Values
# mths_since_recent_inq               114776           9.760910
# emp_title                            74217           6.311646
# emp_length                           72553           6.170134
# num_tl_120dpd_2m                     53751           4.571153
# mo_sin_old_il_acct                   33544           2.852687
# title                                19789           1.682918
# bc_util                              13404           1.139918
# percent_bc_gt_75                     13127           1.116361
# bc_open_to_buy                       12711           1.080983
# mths_since_recent_bc                 11991           1.019752
# revol_util                             698           0.059360
# dti                                    307           0.026108
# avg_cur_bal                             33           0.002806
# zip_code                                21           0.001786
# num_rev_accts                           21           0.001786
# inq_last_6mths                          21           0.001786
# num_tl_90g_dpd_24m                      20           0.001701
# total_bal_ex_mort                       20           0.001701
# mo_sin_rcnt_rev_tl_op                   20           0.001701
# mo_sin_rcnt_tl                          20           0.001701
# hardship_flag                           20           0.001701
# mort_acc                                20           0.001701
# tot_hi_cred_lim                         20           0.001701
# pct_tl_nvr_dlq                          20           0.001701
# total_il_high_credit_limit              20           0.001701
# num_accts_ever_120_pd                   20           0.001701
# num_actv_bc_tl                          20           0.001701
# num_actv_rev_tl                         20           0.001701
# num_bc_sats                             20           0.001701
# num_bc_tl                               20           0.001701
# ...                                    ...                ...
# loan_amnt                               20           0.001701
# delinq_amnt                             20           0.001701
# earliest_cr_line                        20           0.001701
# funded_amnt_inv                         20           0.001701
# term                                    20           0.001701
# int_rate                                20           0.001701
# installment                             20           0.001701
# grade                                   20           0.001701
# sub_grade                               20           0.001701
# home_ownership                          20           0.001701
# annual_inc                              20           0.001701
# verification_status                     20           0.001701
# purpose                                 20           0.001701
# addr_state                              20           0.001701
# delinq_2yrs                             20           0.001701
# open_acc                                20           0.001701
# chargeoff_within_12_mths                20           0.001701
# pub_rec                                 20           0.001701
# revol_bal                               20           0.001701
# total_acc                               20           0.001701
# initial_list_status                     20           0.001701
# collections_12_mths_ex_med              20           0.001701
# application_type                        20           0.001701
# acc_now_delinq                          20           0.001701
# tot_coll_amt                            20           0.001701
# tot_cur_bal                             20           0.001701
# total_rev_hi_lim                        20           0.001701
# acc_open_past_24mths                    20           0.001701
# funded_amnt                             20           0.001701
# debt_settlement_flag                    20           0.001701
#
# [70 rows x 2 columns]

# %%
missing_values_table(test)
# Out:
# Your selected dataframe has 72 columns.
# There are 70 columns that have missing values.
#                             Missing Values  % of Total Values
# emp_title                            12905          10.752195
# emp_length                           10761           8.965856
# mths_since_recent_inq                10403           8.667578
# mo_sin_old_il_acct                    4140           3.449368
# num_tl_120dpd_2m                      3495           2.911966
# bc_util                               2077           1.730516
# percent_bc_gt_75                      1997           1.663862
# bc_open_to_buy                        1994           1.661362
# mths_since_recent_bc                  1859           1.548883
# dti                                    333           0.277449
# revol_util                             184           0.153305
# avg_cur_bal                             23           0.019163
# pct_tl_nvr_dlq                          13           0.010831
# tax_liens                               12           0.009998
# hardship_flag                           12           0.009998
# mo_sin_old_rev_tl_op                    12           0.009998
# mo_sin_rcnt_rev_tl_op                   12           0.009998
# mo_sin_rcnt_tl                          12           0.009998
# mort_acc                                12           0.009998
# total_il_high_credit_limit              12           0.009998
# num_accts_ever_120_pd                   12           0.009998
# num_actv_bc_tl                          12           0.009998
# num_actv_rev_tl                         12           0.009998
# num_bc_sats                             12           0.009998
# num_bc_tl                               12           0.009998
# tot_hi_cred_lim                         12           0.009998
# num_il_tl                               12           0.009998
# num_op_rev_tl                           12           0.009998
# num_rev_accts                           12           0.009998
# delinq_amnt                             12           0.009998
# ...                                    ...                ...
# delinq_2yrs                             12           0.009998
# funded_amnt_inv                         12           0.009998
# term                                    12           0.009998
# int_rate                                12           0.009998
# installment                             12           0.009998
# grade                                   12           0.009998
# sub_grade                               12           0.009998
# home_ownership                          12           0.009998
# annual_inc                              12           0.009998
# verification_status                     12           0.009998
# purpose                                 12           0.009998
# title                                   12           0.009998
# zip_code                                12           0.009998
# addr_state                              12           0.009998
# earliest_cr_line                        12           0.009998
# funded_amnt                             12           0.009998
# inq_last_6mths                          12           0.009998
# open_acc                                12           0.009998
# pub_rec                                 12           0.009998
# revol_bal                               12           0.009998
# total_acc                               12           0.009998
# initial_list_status                     12           0.009998
# collections_12_mths_ex_med              12           0.009998
# application_type                        12           0.009998
# acc_now_delinq                          12           0.009998
# tot_coll_amt                            12           0.009998
# tot_cur_bal                             12           0.009998
# total_rev_hi_lim                        12           0.009998
# acc_open_past_24mths                    12           0.009998
# debt_settlement_flag                    12           0.009998
#
# [70 rows x 2 columns]

# %%
# There're 20 samples in train and 12 samples in test that all features are Null 
pd.set_option('display.max_columns', None)
train[train['loan_amnt'] .isnull()]
# Out:
#          loan_amnt  funded_amnt  funded_amnt_inv term int_rate  installment  \
# 228976         NaN          NaN              NaN  NaN      NaN          NaN
# 228977         NaN          NaN              NaN  NaN      NaN          NaN
# 612770         NaN          NaN              NaN  NaN      NaN          NaN
# 612771         NaN          NaN              NaN  NaN      NaN          NaN
# 733491         NaN          NaN              NaN  NaN      NaN          NaN
# 733492         NaN          NaN              NaN  NaN      NaN          NaN
# 821887         NaN          NaN              NaN  NaN      NaN          NaN
# 821888         NaN          NaN              NaN  NaN      NaN          NaN
# 893845         NaN          NaN              NaN  NaN      NaN          NaN
# 893846         NaN          NaN              NaN  NaN      NaN          NaN
# 960448         NaN          NaN              NaN  NaN      NaN          NaN
# 960449         NaN          NaN              NaN  NaN      NaN          NaN
# 1016468        NaN          NaN              NaN  NaN      NaN          NaN
# 1016469        NaN          NaN              NaN  NaN      NaN          NaN
# 1071660        NaN          NaN              NaN  NaN      NaN          NaN
# 1071661        NaN          NaN              NaN  NaN      NaN          NaN
# 1128547        NaN          NaN              NaN  NaN      NaN          NaN
# 1128548        NaN          NaN              NaN  NaN      NaN          NaN
# 1175872        NaN          NaN              NaN  NaN      NaN          NaN
# 1175873        NaN          NaN              NaN  NaN      NaN          NaN
#
#         grade sub_grade emp_title emp_length home_ownership  annual_inc  \
# 228976    NaN       NaN       NaN        NaN            NaN         NaN
# 228977    NaN       NaN       NaN        NaN            NaN         NaN
# 612770    NaN       NaN       NaN        NaN            NaN         NaN
# 612771    NaN       NaN       NaN        NaN            NaN         NaN
# 733491    NaN       NaN       NaN        NaN            NaN         NaN
# 733492    NaN       NaN       NaN        NaN            NaN         NaN
# 821887    NaN       NaN       NaN        NaN            NaN         NaN
# 821888    NaN       NaN       NaN        NaN            NaN         NaN
# 893845    NaN       NaN       NaN        NaN            NaN         NaN
# 893846    NaN       NaN       NaN        NaN            NaN         NaN
# 960448    NaN       NaN       NaN        NaN            NaN         NaN
# 960449    NaN       NaN       NaN        NaN            NaN         NaN
# 1016468   NaN       NaN       NaN        NaN            NaN         NaN
# 1016469   NaN       NaN       NaN        NaN            NaN         NaN
# 1071660   NaN       NaN       NaN        NaN            NaN         NaN
# 1071661   NaN       NaN       NaN        NaN            NaN         NaN
# 1128547   NaN       NaN       NaN        NaN            NaN         NaN
# 1128548   NaN       NaN       NaN        NaN            NaN         NaN
# 1175872   NaN       NaN       NaN        NaN            NaN         NaN
# 1175873   NaN       NaN       NaN        NaN            NaN         NaN
#
#         verification_status purpose title zip_code addr_state  dti  \
# 228976                  NaN     NaN   NaN      NaN        NaN  NaN
# 228977                  NaN     NaN   NaN      NaN        NaN  NaN
# 612770                  NaN     NaN   NaN      NaN        NaN  NaN
# 612771                  NaN     NaN   NaN      NaN        NaN  NaN
# 733491                  NaN     NaN   NaN      NaN        NaN  NaN
# 733492                  NaN     NaN   NaN      NaN        NaN  NaN
# 821887                  NaN     NaN   NaN      NaN        NaN  NaN
# 821888                  NaN     NaN   NaN      NaN        NaN  NaN
# 893845                  NaN     NaN   NaN      NaN        NaN  NaN
# 893846                  NaN     NaN   NaN      NaN        NaN  NaN
# 960448                  NaN     NaN   NaN      NaN        NaN  NaN
# 960449                  NaN     NaN   NaN      NaN        NaN  NaN
# 1016468                 NaN     NaN   NaN      NaN        NaN  NaN
# 1016469                 NaN     NaN   NaN      NaN        NaN  NaN
# 1071660                 NaN     NaN   NaN      NaN        NaN  NaN
# 1071661                 NaN     NaN   NaN      NaN        NaN  NaN
# 1128547                 NaN     NaN   NaN      NaN        NaN  NaN
# 1128548                 NaN     NaN   NaN      NaN        NaN  NaN
# 1175872                 NaN     NaN   NaN      NaN        NaN  NaN
# 1175873                 NaN     NaN   NaN      NaN        NaN  NaN
#
#          delinq_2yrs earliest_cr_line  inq_last_6mths  open_acc  pub_rec  \
# 228976           NaN              NaN             NaN       NaN      NaN
# 228977           NaN              NaN             NaN       NaN      NaN
# 612770           NaN              NaN             NaN       NaN      NaN
# 612771           NaN              NaN             NaN       NaN      NaN
# 733491           NaN              NaN             NaN       NaN      NaN
# 733492           NaN              NaN             NaN       NaN      NaN
# 821887           NaN              NaN             NaN       NaN      NaN
# 821888           NaN              NaN             NaN       NaN      NaN
# 893845           NaN              NaN             NaN       NaN      NaN
# 893846           NaN              NaN             NaN       NaN      NaN
# 960448           NaN              NaN             NaN       NaN      NaN
# 960449           NaN              NaN             NaN       NaN      NaN
# 1016468          NaN              NaN             NaN       NaN      NaN
# 1016469          NaN              NaN             NaN       NaN      NaN
# 1071660          NaN              NaN             NaN       NaN      NaN
# 1071661          NaN              NaN             NaN       NaN      NaN
# 1128547          NaN              NaN             NaN       NaN      NaN
# 1128548          NaN              NaN             NaN       NaN      NaN
# 1175872          NaN              NaN             NaN       NaN      NaN
# 1175873          NaN              NaN             NaN       NaN      NaN
#
#          revol_bal revol_util  total_acc initial_list_status  \
# 228976         NaN        NaN        NaN                 NaN
# 228977         NaN        NaN        NaN                 NaN
# 612770         NaN        NaN        NaN                 NaN
# 612771         NaN        NaN        NaN                 NaN
# 733491         NaN        NaN        NaN                 NaN
# 733492         NaN        NaN        NaN                 NaN
# 821887         NaN        NaN        NaN                 NaN
# 821888         NaN        NaN        NaN                 NaN
# 893845         NaN        NaN        NaN                 NaN
# 893846         NaN        NaN        NaN                 NaN
# 960448         NaN        NaN        NaN                 NaN
# 960449         NaN        NaN        NaN                 NaN
# 1016468        NaN        NaN        NaN                 NaN
# 1016469        NaN        NaN        NaN                 NaN
# 1071660        NaN        NaN        NaN                 NaN
# 1071661        NaN        NaN        NaN                 NaN
# 1128547        NaN        NaN        NaN                 NaN
# 1128548        NaN        NaN        NaN                 NaN
# 1175872        NaN        NaN        NaN                 NaN
# 1175873        NaN        NaN        NaN                 NaN
#
#          collections_12_mths_ex_med application_type  acc_now_delinq  \
# 228976                          NaN              NaN             NaN
# 228977                          NaN              NaN             NaN
# 612770                          NaN              NaN             NaN
# 612771                          NaN              NaN             NaN
# 733491                          NaN              NaN             NaN
# 733492                          NaN              NaN             NaN
# 821887                          NaN              NaN             NaN
# 821888                          NaN              NaN             NaN
# 893845                          NaN              NaN             NaN
# 893846                          NaN              NaN             NaN
# 960448                          NaN              NaN             NaN
# 960449                          NaN              NaN             NaN
# 1016468                         NaN              NaN             NaN
# 1016469                         NaN              NaN             NaN
# 1071660                         NaN              NaN             NaN
# 1071661                         NaN              NaN             NaN
# 1128547                         NaN              NaN             NaN
# 1128548                         NaN              NaN             NaN
# 1175872                         NaN              NaN             NaN
# 1175873                         NaN              NaN             NaN
#
#          tot_coll_amt  tot_cur_bal  total_rev_hi_lim  acc_open_past_24mths  \
# 228976            NaN          NaN               NaN                   NaN
# 228977            NaN          NaN               NaN                   NaN
# 612770            NaN          NaN               NaN                   NaN
# 612771            NaN          NaN               NaN                   NaN
# 733491            NaN          NaN               NaN                   NaN
# 733492            NaN          NaN               NaN                   NaN
# 821887            NaN          NaN               NaN                   NaN
# 821888            NaN          NaN               NaN                   NaN
# 893845            NaN          NaN               NaN                   NaN
# 893846            NaN          NaN               NaN                   NaN
# 960448            NaN          NaN               NaN                   NaN
# 960449            NaN          NaN               NaN                   NaN
# 1016468           NaN          NaN               NaN                   NaN
# 1016469           NaN          NaN               NaN                   NaN
# 1071660           NaN          NaN               NaN                   NaN
# 1071661           NaN          NaN               NaN                   NaN
# 1128547           NaN          NaN               NaN                   NaN
# 1128548           NaN          NaN               NaN                   NaN
# 1175872           NaN          NaN               NaN                   NaN
# 1175873           NaN          NaN               NaN                   NaN
#
#          avg_cur_bal  bc_open_to_buy  bc_util  chargeoff_within_12_mths  \
# 228976           NaN             NaN      NaN                       NaN
# 228977           NaN             NaN      NaN                       NaN
# 612770           NaN             NaN      NaN                       NaN
# 612771           NaN             NaN      NaN                       NaN
# 733491           NaN             NaN      NaN                       NaN
# 733492           NaN             NaN      NaN                       NaN
# 821887           NaN             NaN      NaN                       NaN
# 821888           NaN             NaN      NaN                       NaN
# 893845           NaN             NaN      NaN                       NaN
# 893846           NaN             NaN      NaN                       NaN
# 960448           NaN             NaN      NaN                       NaN
# 960449           NaN             NaN      NaN                       NaN
# 1016468          NaN             NaN      NaN                       NaN
# 1016469          NaN             NaN      NaN                       NaN
# 1071660          NaN             NaN      NaN                       NaN
# 1071661          NaN             NaN      NaN                       NaN
# 1128547          NaN             NaN      NaN                       NaN
# 1128548          NaN             NaN      NaN                       NaN
# 1175872          NaN             NaN      NaN                       NaN
# 1175873          NaN             NaN      NaN                       NaN
#
#          delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  \
# 228976           NaN                 NaN                   NaN
# 228977           NaN                 NaN                   NaN
# 612770           NaN                 NaN                   NaN
# 612771           NaN                 NaN                   NaN
# 733491           NaN                 NaN                   NaN
# 733492           NaN                 NaN                   NaN
# 821887           NaN                 NaN                   NaN
# 821888           NaN                 NaN                   NaN
# 893845           NaN                 NaN                   NaN
# 893846           NaN                 NaN                   NaN
# 960448           NaN                 NaN                   NaN
# 960449           NaN                 NaN                   NaN
# 1016468          NaN                 NaN                   NaN
# 1016469          NaN                 NaN                   NaN
# 1071660          NaN                 NaN                   NaN
# 1071661          NaN                 NaN                   NaN
# 1128547          NaN                 NaN                   NaN
# 1128548          NaN                 NaN                   NaN
# 1175872          NaN                 NaN                   NaN
# 1175873          NaN                 NaN                   NaN
#
#          mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 228976                     NaN             NaN       NaN
# 228977                     NaN             NaN       NaN
# 612770                     NaN             NaN       NaN
# 612771                     NaN             NaN       NaN
# 733491                     NaN             NaN       NaN
# 733492                     NaN             NaN       NaN
# 821887                     NaN             NaN       NaN
# 821888                     NaN             NaN       NaN
# 893845                     NaN             NaN       NaN
# 893846                     NaN             NaN       NaN
# 960448                     NaN             NaN       NaN
# 960449                     NaN             NaN       NaN
# 1016468                    NaN             NaN       NaN
# 1016469                    NaN             NaN       NaN
# 1071660                    NaN             NaN       NaN
# 1071661                    NaN             NaN       NaN
# 1128547                    NaN             NaN       NaN
# 1128548                    NaN             NaN       NaN
# 1175872                    NaN             NaN       NaN
# 1175873                    NaN             NaN       NaN
#
#          mths_since_recent_bc  mths_since_recent_inq  num_accts_ever_120_pd  \
# 228976                    NaN                    NaN                    NaN
# 228977                    NaN                    NaN                    NaN
# 612770                    NaN                    NaN                    NaN
# 612771                    NaN                    NaN                    NaN
# 733491                    NaN                    NaN                    NaN
# 733492                    NaN                    NaN                    NaN
# 821887                    NaN                    NaN                    NaN
# 821888                    NaN                    NaN                    NaN
# 893845                    NaN                    NaN                    NaN
# 893846                    NaN                    NaN                    NaN
# 960448                    NaN                    NaN                    NaN
# 960449                    NaN                    NaN                    NaN
# 1016468                   NaN                    NaN                    NaN
# 1016469                   NaN                    NaN                    NaN
# 1071660                   NaN                    NaN                    NaN
# 1071661                   NaN                    NaN                    NaN
# 1128547                   NaN                    NaN                    NaN
# 1128548                   NaN                    NaN                    NaN
# 1175872                   NaN                    NaN                    NaN
# 1175873                   NaN                    NaN                    NaN
#
#          num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  \
# 228976              NaN              NaN          NaN        NaN        NaN
# 228977              NaN              NaN          NaN        NaN        NaN
# 612770              NaN              NaN          NaN        NaN        NaN
# 612771              NaN              NaN          NaN        NaN        NaN
# 733491              NaN              NaN          NaN        NaN        NaN
# 733492              NaN              NaN          NaN        NaN        NaN
# 821887              NaN              NaN          NaN        NaN        NaN
# 821888              NaN              NaN          NaN        NaN        NaN
# 893845              NaN              NaN          NaN        NaN        NaN
# 893846              NaN              NaN          NaN        NaN        NaN
# 960448              NaN              NaN          NaN        NaN        NaN
# 960449              NaN              NaN          NaN        NaN        NaN
# 1016468             NaN              NaN          NaN        NaN        NaN
# 1016469             NaN              NaN          NaN        NaN        NaN
# 1071660             NaN              NaN          NaN        NaN        NaN
# 1071661             NaN              NaN          NaN        NaN        NaN
# 1128547             NaN              NaN          NaN        NaN        NaN
# 1128548             NaN              NaN          NaN        NaN        NaN
# 1175872             NaN              NaN          NaN        NaN        NaN
# 1175873             NaN              NaN          NaN        NaN        NaN
#
#          num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  num_sats  \
# 228976             NaN            NaN                  NaN       NaN
# 228977             NaN            NaN                  NaN       NaN
# 612770             NaN            NaN                  NaN       NaN
# 612771             NaN            NaN                  NaN       NaN
# 733491             NaN            NaN                  NaN       NaN
# 733492             NaN            NaN                  NaN       NaN
# 821887             NaN            NaN                  NaN       NaN
# 821888             NaN            NaN                  NaN       NaN
# 893845             NaN            NaN                  NaN       NaN
# 893846             NaN            NaN                  NaN       NaN
# 960448             NaN            NaN                  NaN       NaN
# 960449             NaN            NaN                  NaN       NaN
# 1016468            NaN            NaN                  NaN       NaN
# 1016469            NaN            NaN                  NaN       NaN
# 1071660            NaN            NaN                  NaN       NaN
# 1071661            NaN            NaN                  NaN       NaN
# 1128547            NaN            NaN                  NaN       NaN
# 1128548            NaN            NaN                  NaN       NaN
# 1175872            NaN            NaN                  NaN       NaN
# 1175873            NaN            NaN                  NaN       NaN
#
#          num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 228976                NaN           NaN                 NaN
# 228977                NaN           NaN                 NaN
# 612770                NaN           NaN                 NaN
# 612771                NaN           NaN                 NaN
# 733491                NaN           NaN                 NaN
# 733492                NaN           NaN                 NaN
# 821887                NaN           NaN                 NaN
# 821888                NaN           NaN                 NaN
# 893845                NaN           NaN                 NaN
# 893846                NaN           NaN                 NaN
# 960448                NaN           NaN                 NaN
# 960449                NaN           NaN                 NaN
# 1016468               NaN           NaN                 NaN
# 1016469               NaN           NaN                 NaN
# 1071660               NaN           NaN                 NaN
# 1071661               NaN           NaN                 NaN
# 1128547               NaN           NaN                 NaN
# 1128548               NaN           NaN                 NaN
# 1175872               NaN           NaN                 NaN
# 1175873               NaN           NaN                 NaN
#
#          num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# 228976                  NaN             NaN               NaN
# 228977                  NaN             NaN               NaN
# 612770                  NaN             NaN               NaN
# 612771                  NaN             NaN               NaN
# 733491                  NaN             NaN               NaN
# 733492                  NaN             NaN               NaN
# 821887                  NaN             NaN               NaN
# 821888                  NaN             NaN               NaN
# 893845                  NaN             NaN               NaN
# 893846                  NaN             NaN               NaN
# 960448                  NaN             NaN               NaN
# 960449                  NaN             NaN               NaN
# 1016468                 NaN             NaN               NaN
# 1016469                 NaN             NaN               NaN
# 1071660                 NaN             NaN               NaN
# 1071661                 NaN             NaN               NaN
# 1128547                 NaN             NaN               NaN
# 1128548                 NaN             NaN               NaN
# 1175872                 NaN             NaN               NaN
# 1175873                 NaN             NaN               NaN
#
#          pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bal_ex_mort  \
# 228976                    NaN        NaN              NaN                NaN
# 228977                    NaN        NaN              NaN                NaN
# 612770                    NaN        NaN              NaN                NaN
# 612771                    NaN        NaN              NaN                NaN
# 733491                    NaN        NaN              NaN                NaN
# 733492                    NaN        NaN              NaN                NaN
# 821887                    NaN        NaN              NaN                NaN
# 821888                    NaN        NaN              NaN                NaN
# 893845                    NaN        NaN              NaN                NaN
# 893846                    NaN        NaN              NaN                NaN
# 960448                    NaN        NaN              NaN                NaN
# 960449                    NaN        NaN              NaN                NaN
# 1016468                   NaN        NaN              NaN                NaN
# 1016469                   NaN        NaN              NaN                NaN
# 1071660                   NaN        NaN              NaN                NaN
# 1071661                   NaN        NaN              NaN                NaN
# 1128547                   NaN        NaN              NaN                NaN
# 1128548                   NaN        NaN              NaN                NaN
# 1175872                   NaN        NaN              NaN                NaN
# 1175873                   NaN        NaN              NaN                NaN
#
#          total_bc_limit  total_il_high_credit_limit hardship_flag  \
# 228976              NaN                         NaN           NaN
# 228977              NaN                         NaN           NaN
# 612770              NaN                         NaN           NaN
# 612771              NaN                         NaN           NaN
# 733491              NaN                         NaN           NaN
# 733492              NaN                         NaN           NaN
# 821887              NaN                         NaN           NaN
# 821888              NaN                         NaN           NaN
# 893845              NaN                         NaN           NaN
# 893846              NaN                         NaN           NaN
# 960448              NaN                         NaN           NaN
# 960449              NaN                         NaN           NaN
# 1016468             NaN                         NaN           NaN
# 1016469             NaN                         NaN           NaN
# 1071660             NaN                         NaN           NaN
# 1071661             NaN                         NaN           NaN
# 1128547             NaN                         NaN           NaN
# 1128548             NaN                         NaN           NaN
# 1175872             NaN                         NaN           NaN
# 1175873             NaN                         NaN           NaN
#
#         debt_settlement_flag  year  target
# 228976                   NaN  2014       1
# 228977                   NaN  2014       1
# 612770                   NaN  2015       1
# 612771                   NaN  2015       1
# 733491                   NaN  2016       1
# 733492                   NaN  2016       1
# 821887                   NaN  2016       1
# 821888                   NaN  2016       1
# 893845                   NaN  2016       1
# 893846                   NaN  2016       1
# 960448                   NaN  2016       1
# 960449                   NaN  2016       1
# 1016468                  NaN  2017       1
# 1016469                  NaN  2017       1
# 1071660                  NaN  2017       1
# 1071661                  NaN  2017       1
# 1128547                  NaN  2017       1
# 1128548                  NaN  2017       1
# 1175872                  NaN  2017       1
# 1175873                  NaN  2017       1

# %%
# Locate these rows
Index1 = train[np.isnan(train['loan_amnt'])].index
Index2 = test[np.isnan(test['loan_amnt'])].index
# Delete them
train.drop(Index1,inplace=True)
test.drop(Index2,inplace=True)

# %%
missing_values_table(train)
# Out:
# Your selected dataframe has 72 columns.
# There are 16 columns that have missing values.
#                        Missing Values  % of Total Values
# mths_since_recent_inq          114756           9.759375
# emp_title                       74197           6.310052
# emp_length                      72533           6.168538
# num_tl_120dpd_2m                53731           4.569530
# mo_sin_old_il_acct              33524           2.851034
# title                           19769           1.681246
# bc_util                         13384           1.138237
# percent_bc_gt_75                13107           1.114679
# bc_open_to_buy                  12691           1.079301
# mths_since_recent_bc            11971           1.018069
# revol_util                        678           0.057660
# dti                               287           0.024408
# avg_cur_bal                        13           0.001106
# zip_code                            1           0.000085
# inq_last_6mths                      1           0.000085
# num_rev_accts                       1           0.000085

# %%
missing_values_table(test)
# Out:
# Your selected dataframe has 72 columns.
# There are 13 columns that have missing values.
#                        Missing Values  % of Total Values
# emp_title                       12893          10.743271
# emp_length                      10749           8.956754
# mths_since_recent_inq           10391           8.658445
# mo_sin_old_il_acct               4128           3.439713
# num_tl_120dpd_2m                 3483           2.902258
# bc_util                          2065           1.720690
# percent_bc_gt_75                 1985           1.654029
# bc_open_to_buy                   1982           1.651529
# mths_since_recent_bc             1847           1.539038
# dti                               321           0.267478
# revol_util                        172           0.143321
# avg_cur_bal                        11           0.009166
# pct_tl_nvr_dlq                      1           0.000833

# %% [markdown]
# Analyze from bottom to top:<br>
# For **zip_code**, theoretically, we can try to add latitude, longitude, local population and local economic data to make it more informative. However, as I am not quite familiar with US postal code distribution, I will delete this feature anyway.

# %%
train = train.drop(labels='zip_code', axis=1)
test = test.drop(labels='zip_code', axis=1)

# %% [markdown]
# For **inq_last_6mths**(The number of inquiries in past 6 months (excluding auto and mortgage inquiries).):
# Since there's only one missing value, and it varies from 0 to 6. Use the mode (most frequent value) to replace it.

# %%
train['inq_last_6mths'].value_counts()
# Out:
# 0.0    693809
# 1.0    316570
# 2.0    110438
# 3.0     38401
# 4.0     11894
# 5.0      4199
# 6.0       542
# Name: inq_last_6mths, dtype: int64

# %%
train['inq_last_6mths'] = train['inq_last_6mths'].fillna(value=0.0)
test['pct_tl_nvr_dlq'] = test['pct_tl_nvr_dlq'].fillna(value=100.0)

# %% [markdown]
# For **num_rev_accts**(Number of revolving accounts):<br>
# It's a continuous feature, so it is reasonable to fill with a median value

# %%
num_rev_accts_median = train['num_rev_accts'].median()
train['num_rev_accts'] = train['num_rev_accts'].fillna(value=num_rev_accts_median)
#train['num_rev_accts'] = train['num_rev_accts'].fillna(value=train['num_rev_accts'].median)

# %% [markdown]
# For **avg_cur_bal**(Average current balance of all accounts): use median value to fill in

# %%
avg_cur_bal_median = train['avg_cur_bal'].median()
train['avg_cur_bal'] = train['avg_cur_bal'].fillna(value=avg_cur_bal_median)
test['avg_cur_bal'] = test['avg_cur_bal'].fillna(value=avg_cur_bal_median)
#train['avg_cur_bal'] = train['avg_cur_bal'].fillna(value=train['avg_cur_bal'].median)

# %% [markdown]
# For **dti**(A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income):

# %%
# fill the missing value with the median value
dti_median = train['dti'].median()
train['dti'] = train['dti'].fillna(value=dti_median)
test['dti'] = test['dti'].fillna(value=dti_median)

# %% [markdown]
# For **revol_util**(Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.):<br>
# The data type of this feature is object, and it is a percentage variable. Need to transfer to float, and parse the data to delete the '%'

# %%
train['revol_util'] = train['revol_util'].str.strip("%").astype(float)/100
test['revol_util'] = test['revol_util'].str.strip("%").astype(float)/100
revol_util_median = train['revol_util'].median()
train['revol_util'] = train['revol_util'].fillna(value=revol_util_median)
test['revol_util'] = test['revol_util'].fillna(value=revol_util_median)

# %% [markdown]
# For **mths_since_recent_bc**(Months since most recent bankcard account opened.) <br>**mths_since_recent_inq**(Months since most recent inquire.)

# %%
mths_recent_bc_median = train['mths_since_recent_bc'].median()
mths_recent_inq_median = train['mths_since_recent_inq'].median()
train['mths_since_recent_bc'] = train['mths_since_recent_bc'].fillna(value = mths_recent_bc_median)
train['mths_since_recent_inq'] = train['mths_since_recent_inq'].fillna(value = mths_recent_inq_median)
test['mths_since_recent_bc'] = test['mths_since_recent_bc'].fillna(value = mths_recent_bc_median)
test['mths_since_recent_inq'] = test['mths_since_recent_inq'].fillna(value = mths_recent_inq_median)

# %% [markdown]
# For **num_tl_120dpd_2m** (Number of accounts currently 120 days past due (updated in past 2 months)), use most frequent value 0 to fill in the missing values

# %%
train['num_tl_120dpd_2m'] = train['num_tl_120dpd_2m'].fillna(value=0)
test['num_tl_120dpd_2m'] = test['num_tl_120dpd_2m'].fillna(value=0)

# %% [markdown]
# For **bc_open_to_buy** (Total open to buy on revolving bankcards),<br> **bc_util** (Ratio of total current balance to high credit/credit limit for all bankcard accounts.), <br> **percent_bc_gt_75** (Percentage of all bankcard accounts > 75% of limit), <br> **mo_sin_old_il_acct**(Months since oldest bank installment account opened.), <br>  use the fill in with median value strategy :

# %%
bc_open_to_buy_median = train['bc_open_to_buy'].median()
train['bc_open_to_buy'] = train['bc_open_to_buy'].fillna(value=bc_open_to_buy_median)
test['bc_open_to_buy'] = test['bc_open_to_buy'].fillna(value=bc_open_to_buy_median)

# %%
bc_util_median = train['bc_util'].median()
train['bc_util'] = train['bc_util'].fillna(value=bc_util_median)
test['bc_util'] = test['bc_util'].fillna(value=bc_util_median)

# %%
percent_bc_gt_75_median = train['percent_bc_gt_75'].median()
train['percent_bc_gt_75'] = train['percent_bc_gt_75'].fillna(value=percent_bc_gt_75_median)
test['percent_bc_gt_75'] = test['percent_bc_gt_75'].fillna(value=percent_bc_gt_75_median)

# %%
mo_sin_old_il_acct_median = train['mo_sin_old_il_acct'].median()
train['mo_sin_old_il_acct'] = train['mo_sin_old_il_acct'].fillna(value=mo_sin_old_il_acct_median)
test['mo_sin_old_il_acct'] = test['mo_sin_old_il_acct'].fillna(value=mo_sin_old_il_acct_median)

# %%
# emp_title contains too many categories, it is better to delete it
train = train.drop(labels='emp_title', axis=1)
test = test.drop(labels='emp_title', axis=1)

# %%
# for 'title', we will fill the missing value with another category, named as "missing"
train['title'] = train['title'].fillna(value='Missing')

# %% [markdown]
# For **employ_length**, usually it is a positive relationship with annual income based on common sense. Though it is not absolute, but let's explore to see the correlation of these two variables below.

# %%
def str_parser(x):
    """ function to parse `int_rate` and `revol_util` """
    if 'years' in str(x):
        return str(x).replace('years', 'year')
    if '< 1' in str(x):
        return str(x).replace('< 1', '0')
    if '+' in str(x):
        return str(x).replace('+', '')
    return x

# %%
train['emp_length'] = train['emp_length'].apply(str_parser)
test['emp_length'] = test['emp_length'].apply(str_parser)

# %%
train['emp_length'] = train['emp_length'].str.strip("year").astype(float)
test['emp_length'] = test['emp_length'].str.strip("year").astype(float)

# %%
# check their correlation first
employ_length_salary = pd.DataFrame({'x':train['emp_length'], 'y':train['annual_inc']})
employ_length_salary.corr()
# Out:
#          x        y
# x  1.00000  0.03832
# y  0.03832  1.00000

# %% [markdown]
# As shown, surprisingly, we find that these two columns have few relationship. Choose mode method to fill in the missing value might be better here.

# %%
emp_length_mode = train['emp_length'].mode()[0]
train['emp_length'] = train['emp_length'].fillna(value=emp_length_mode)
test['emp_length'] = test['emp_length'].fillna(value=emp_length_mode)

# %%
missing_values_table(train)
# Out:
# Your selected dataframe has 70 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
missing_values_table(test)
# Out:
# Your selected dataframe has 70 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
# save to disk
train.to_csv('./train_clean.csv', index=False)
test.to_csv('./test_clean.csv', index=False)
